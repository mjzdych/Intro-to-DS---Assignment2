# %% [markdown]
# **Assignment2 - Visualisations**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt

# %%
file = 'Data_related_jobs_glassdoor.csv'
df = pd.read_csv(file, index_col=0)
ten_rows = df.head(10)
display(ten_rows)
# Out:
#                                                                         job title  \
# company
# Microsoft                                                Data & Applied Scientist
# UT Southwestern Medical Center        Data Scientist or Bioinformatician (remote)
# Notion                                                     Data Scientist, Growth
# Net2Aspire                                                     Jr. Data Scientist
# Ntropy Network                                                     Data Scientist
# PayPal                                                             Data Scientist
# Pomeroy Technologies, LLC.                                         Data Scientist
# Delta                           Associate Data Scientist, Operations Decision ...
# Booz Allen Hamilton                        Tech Excellence Data Scientist, Junior
# Starz                                                              Data Scientist
#
#                                       location  \
# ...
